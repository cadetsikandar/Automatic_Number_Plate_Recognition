# %%
# !pip uninstall opencv-python-headless -y
# !pip install opencv-python
# Out:
# Found existing installation: opencv-python-headless 4.12.0.88
# Uninstalling opencv-python-headless-4.12.0.88:
#   Successfully uninstalled opencv-python-headless-4.12.0.88
# Requirement already satisfied: opencv-python in c:\users\victus\anaconda3\envs\number_plate\lib\site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in c:\users\victus\anaconda3\envs\number_plate\lib\site-packages (from opencv-python) (2.2.6)

# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLOv8n model
model = YOLO("yolov8n.pt")
# Train the model on the COCO8 example dataset for 100 epochs
results = model.train(data="dataset/data.yaml", epochs=100, imgsz=640)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2/6.2MB 1.9MB/s 3.4s0.0s8s
# New https://pypi.org/project/ultralytics/8.3.197 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.191  Python-3.10.18 torch-2.8.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=dataset/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs\detect\train2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# Model summary: 129 layers, 3,011,043 parameters, 3,011,027 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4/5.4MB 720.5KB/s 7.6s1s9ssss
# AMP: checks passed
# train: Fast image access  (ping: 0.30.0 ms, read: 3.60.7 MB/s, size: 81.0 KB)
# train: Scanning C:\Users\VICTUS\Desktop\Number plate\dataset\train\labels... 621 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 622/622 139.6it/s 4.5s0.1s
# train: New cache created: C:\Users\VICTUS\Desktop\Number plate\dataset\train\labels.cache
# val: Fast image access  (ping: 0.90.7 ms, read: 2.60.7 MB/s, size: 67.9 KB)
# val: Scanning C:\Users\VICTUS\Desktop\Number plate\dataset\valid\labels.cache... 60 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 60/60 11996.3it/s 0.0s
# Plotting labels to runs\detect\train2\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs\detect\train2
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      1.93G       1.58      3.073      1.465         28        640: 100% ━━━━━━━━━━━━ 39/39 1.8it/s 21.8s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.6it/s 1.2s<2.2s
#                    all         60         63    0.00283       0.81      0.182     0.0633
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.25G      1.543      2.255      1.407         29        640: 100% ━━━━━━━━━━━━ 39/39 3.3it/s 11.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s<1.3s
#                    all         60         63      0.783      0.229      0.382      0.158
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.26G      1.663      2.078      1.478         21        640: 100% ━━━━━━━━━━━━ 39/39 3.0it/s 13.1s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s<1.3s
#                    all         60         63      0.203      0.492      0.175     0.0775
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      2.26G      1.595      1.812      1.438         20        640: 100% ━━━━━━━━━━━━ 39/39 3.7it/s 10.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s<1.3s
#                    all         60         63      0.274      0.365       0.21      0.105
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      2.26G      1.575      1.553      1.447         26        640: 100% ━━━━━━━━━━━━ 39/39 3.3it/s 11.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.0s<2.4s
#                    all         60         63     0.0621      0.365     0.0648     0.0306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      2.28G      1.573      1.446       1.44         17        640: 100% ━━━━━━━━━━━━ 39/39 3.3it/s 11.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s<1.3s
#                    all         60         63      0.627      0.603      0.692      0.325
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100       2.3G      1.527      1.356      1.401         28        640: 100% ━━━━━━━━━━━━ 39/39 3.4it/s 11.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.7it/s 0.8s<1.4s
#                    all         60         63      0.848       0.62      0.759      0.416
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      2.31G      1.489      1.217      1.361         24        640: 100% ━━━━━━━━━━━━ 39/39 3.8it/s 10.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.2s
#                    all         60         63      0.755      0.841      0.807      0.433
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      2.33G      1.452      1.186      1.363         27        640: 100% ━━━━━━━━━━━━ 39/39 3.8it/s 10.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s<1.2s
#                    all         60         63      0.836      0.649      0.715      0.387
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      2.35G      1.419      1.089      1.345         20        640: 100% ━━━━━━━━━━━━ 39/39 3.2it/s 12.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.2s
#                    all         60         63      0.837       0.81      0.864      0.442
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      2.37G      1.413      1.069      1.313         16        640: 100% ━━━━━━━━━━━━ 39/39 3.6it/s 10.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.1it/s 0.7s<1.1s
#                    all         60         63      0.816       0.73      0.838      0.424
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      2.38G      1.404      1.095      1.313         26        640: 100% ━━━━━━━━━━━━ 39/39 3.4it/s 11.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.2s
#                    all         60         63      0.832       0.81      0.842      0.417
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100       2.4G      1.399      1.026      1.302         27        640: 100% ━━━━━━━━━━━━ 39/39 3.6it/s 10.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s<1.3s
#                    all         60         63      0.897      0.832      0.886      0.459
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      2.42G      1.362     0.9975      1.298         13        640: 100% ━━━━━━━━━━━━ 39/39 3.6it/s 10.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s<1.2s
#                    all         60         63      0.863      0.802      0.885      0.475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      2.42G      1.301       0.96      1.269         19        640: 100% ━━━━━━━━━━━━ 39/39 3.6it/s 10.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s<1.2s
#                    all         60         63      0.851      0.817      0.856      0.441
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      2.42G      1.333     0.9383      1.261         20        640: 100% ━━━━━━━━━━━━ 39/39 3.7it/s 10.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.4it/s 0.8s<1.6s
#                    all         60         63      0.902      0.762      0.853      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      2.42G      1.307     0.9003      1.252         24        640: 100% ━━━━━━━━━━━━ 39/39 3.0it/s 13.1s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.3it/s 0.9s<1.9s
#                    all         60         63      0.882      0.829      0.914      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      2.42G      1.261     0.8572       1.22         24        640: 100% ━━━━━━━━━━━━ 39/39 3.6it/s 11.0s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.5it/s 0.8s<1.5s
#                    all         60         63      0.863      0.857      0.889      0.501
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      2.42G      1.217     0.8278      1.196         24        640: 100% ━━━━━━━━━━━━ 39/39 3.3it/s 11.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.2s
#                    all         60         63      0.835      0.746      0.822      0.438
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      2.42G      1.251     0.8563      1.225         22        640: 100% ━━━━━━━━━━━━ 39/39 3.3it/s 11.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.1it/s 0.6s<1.1s
#                    all         60         63      0.934      0.746      0.849       0.48
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      2.42G      1.247     0.8283      1.208         20        640: 100% ━━━━━━━━━━━━ 39/39 3.2it/s 12.0s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.3it/s 0.6s<1.1s
#                    all         60         63      0.816      0.776      0.838      0.467
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      2.42G       1.22     0.8248      1.195         21        640: 100% ━━━━━━━━━━━━ 39/39 3.5it/s 11.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.1it/s 0.7s<1.1s
#                    all         60         63      0.749       0.76      0.782      0.441
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      2.42G      1.193     0.8042      1.162         17        640: 100% ━━━━━━━━━━━━ 39/39 3.1it/s 12.4s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.1s
#                    all         60         63      0.927      0.803      0.877      0.504
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      2.42G      1.172     0.7893      1.173         19        640: 100% ━━━━━━━━━━━━ 39/39 3.2it/s 12.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.6it/s 0.8s<1.5s
#                    all         60         63      0.878      0.921      0.924      0.489
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      2.42G      1.167     0.7741       1.15         25        640: 100% ━━━━━━━━━━━━ 39/39 3.0it/s 12.9s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s<1.3s
#                    all         60         63      0.888      0.825      0.865      0.454
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      2.42G      1.141     0.7433      1.154         25        640: 100% ━━━━━━━━━━━━ 39/39 3.4it/s 11.5s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.2s
#                    all         60         63      0.845      0.841      0.847      0.473
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      2.42G      1.097      0.757      1.134         21        640: 100% ━━━━━━━━━━━━ 39/39 3.4it/s 11.5s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s<1.3s
#                    all         60         63      0.879      0.857      0.886      0.472
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      2.42G      1.103     0.7213      1.132         17        640: 100% ━━━━━━━━━━━━ 39/39 3.3it/s 11.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s<1.2s
#                    all         60         63      0.911      0.809      0.869      0.495
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      2.42G      1.086     0.7332      1.132         23        640: 100% ━━━━━━━━━━━━ 39/39 3.2it/s 12.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.7it/s 0.7s<1.4s
#                    all         60         63      0.885      0.857      0.862      0.488
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      2.42G      1.077     0.7017      1.109         18        640: 100% ━━━━━━━━━━━━ 39/39 3.2it/s 12.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.5it/s 0.8s<1.5s
#                    all         60         63       0.85      0.778      0.871      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      2.42G       1.09     0.7324      1.134         22        640: 100% ━━━━━━━━━━━━ 39/39 3.0it/s 13.1s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.3it/s 0.9s<1.7s
#                    all         60         63      0.885      0.859      0.933      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      2.42G      1.064     0.7089      1.109         17        640: 100% ━━━━━━━━━━━━ 39/39 3.0it/s 12.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s<1.3s
#                    all         60         63      0.847      0.881      0.884      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      2.42G       1.03     0.6665      1.103         19        640: 100% ━━━━━━━━━━━━ 39/39 3.0it/s 13.0s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s<1.3s
#                    all         60         63      0.942      0.778      0.837      0.453
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      2.42G      0.985     0.6668      1.081         19        640: 100% ━━━━━━━━━━━━ 39/39 3.7it/s 10.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.2it/s 0.6s<1.1s
#                    all         60         63      0.906      0.825      0.873      0.491
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      2.42G     0.9904     0.6737      1.086         19        640: 100% ━━━━━━━━━━━━ 39/39 3.6it/s 11.0s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s<1.2s
#                    all         60         63      0.901      0.873      0.891      0.489
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      2.42G      0.968      0.627      1.057         21        640: 100% ━━━━━━━━━━━━ 39/39 3.8it/s 10.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.2s
#                    all         60         63      0.929      0.833      0.882      0.476
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      2.42G     0.9883     0.6661      1.103         22        640: 100% ━━━━━━━━━━━━ 39/39 3.3it/s 12.0s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.7it/s 0.7s<1.3s
#                    all         60         63      0.882      0.905      0.902      0.484
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      2.42G     0.9563      0.636      1.061         23        640: 100% ━━━━━━━━━━━━ 39/39 3.7it/s 10.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.2it/s 0.6s<1.1s
#                    all         60         63      0.898      0.839      0.883      0.463
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      2.42G     0.9776     0.6372      1.061         21        640: 100% ━━━━━━━━━━━━ 39/39 3.7it/s 10.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.2it/s 0.6s<1.1s
#                    all         60         63      0.905      0.857      0.902      0.487
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      2.42G      0.942     0.6014      1.043         27        640: 100% ━━━━━━━━━━━━ 39/39 3.4it/s 11.5s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s<1.2s
#                    all         60         63      0.801      0.825      0.839      0.456
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      2.42G     0.9053     0.6059      1.037         22        640: 100% ━━━━━━━━━━━━ 39/39 3.7it/s 10.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s<1.2s
#                    all         60         63      0.914      0.839      0.876      0.491
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      2.42G     0.9063     0.6023      1.023         18        640: 100% ━━━━━━━━━━━━ 39/39 3.9it/s 10.0s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s<1.2s
#                    all         60         63      0.831      0.889      0.899      0.456
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      2.42G     0.9334     0.6049      1.048         19        640: 100% ━━━━━━━━━━━━ 39/39 3.6it/s 10.9s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s<1.2s
#                    all         60         63      0.915      0.852      0.873      0.498
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      2.42G     0.8645     0.5785      1.026         28        640: 100% ━━━━━━━━━━━━ 39/39 3.8it/s 10.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.1it/s 0.6s<1.2s
#                    all         60         63      0.926      0.792      0.849      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      2.42G     0.8814     0.5746      1.012         19        640: 100% ━━━━━━━━━━━━ 39/39 3.6it/s 10.9s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.7it/s 1.2s<2.2s
#                    all         60         63      0.945      0.821      0.879      0.505
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      2.42G     0.8827     0.5795      1.011         27        640: 100% ━━━━━━━━━━━━ 39/39 3.5it/s 11.0s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s<1.2s
#                    all         60         63      0.939      0.794      0.847      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      2.42G     0.8622     0.5567       1.01         20        640: 100% ━━━━━━━━━━━━ 39/39 3.3it/s 11.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.2it/s 0.6s<1.1s
#                    all         60         63      0.913      0.857      0.886      0.492
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      2.42G     0.8547     0.5481      1.004         23        640: 100% ━━━━━━━━━━━━ 39/39 3.7it/s 10.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.2s
#                    all         60         63      0.948      0.871      0.899      0.491
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      2.42G     0.8099     0.5257     0.9964         26        640: 100% ━━━━━━━━━━━━ 39/39 3.5it/s 11.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.2s
#                    all         60         63      0.903      0.883      0.913      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      2.42G      0.822     0.5421     0.9821         18        640: 100% ━━━━━━━━━━━━ 39/39 3.8it/s 10.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.5it/s 0.8s<1.4s
#                    all         60         63       0.87       0.85      0.884      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      2.42G     0.8144     0.5425     0.9831         27        640: 100% ━━━━━━━━━━━━ 39/39 3.2it/s 12.2s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.5it/s 0.8s<1.4s
#                    all         60         63      0.919      0.902      0.908      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      2.42G     0.8077     0.5295     0.9858         31        640: 100% ━━━━━━━━━━━━ 39/39 3.1it/s 12.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.1s
#                    all         60         63      0.873      0.876      0.905       0.51
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      2.42G      0.817      0.533     0.9906         25        640: 100% ━━━━━━━━━━━━ 39/39 3.0it/s 13.0s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.3it/s 0.9s<1.6s
#                    all         60         63       0.91      0.857      0.871      0.497
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      2.42G     0.7807     0.5168     0.9702         24        640: 100% ━━━━━━━━━━━━ 39/39 3.5it/s 11.0s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.2s
#                    all         60         63      0.932       0.87      0.896      0.502
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      2.42G     0.7704     0.5404     0.9725         20        640: 100% ━━━━━━━━━━━━ 39/39 3.6it/s 10.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.1it/s 0.7s<1.2s
#                    all         60         63      0.945      0.817      0.882      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      2.42G     0.7665     0.5021     0.9692         30        640: 100% ━━━━━━━━━━━━ 39/39 3.6it/s 11.0s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s<2.0s
#                    all         60         63       0.93      0.889      0.888      0.504
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      2.42G     0.7762     0.5153     0.9656         19        640: 100% ━━━━━━━━━━━━ 39/39 3.4it/s 11.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.7it/s 0.7s<1.5s
#                    all         60         63      0.929      0.835      0.894      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      2.42G     0.7541     0.4928     0.9582         21        640: 100% ━━━━━━━━━━━━ 39/39 3.4it/s 11.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s<1.2s
#                    all         60         63       0.96      0.841      0.909      0.484
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      2.42G     0.7512      0.496     0.9529         22        640: 100% ━━━━━━━━━━━━ 39/39 3.1it/s 12.5s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s<1.3s
#                    all         60         63      0.867      0.934      0.913      0.475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      2.42G     0.7391     0.4813     0.9505         26        640: 100% ━━━━━━━━━━━━ 39/39 3.7it/s 10.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.2s
#                    all         60         63      0.931      0.863      0.896      0.493
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      2.42G     0.7387     0.4848     0.9505         31        640: 100% ━━━━━━━━━━━━ 39/39 3.7it/s 10.5s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.3s
#                    all         60         63      0.881      0.889      0.888      0.503
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      2.42G     0.7394     0.4953     0.9518         21        640: 100% ━━━━━━━━━━━━ 39/39 3.7it/s 10.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.7it/s 0.8s<1.4s
#                    all         60         63      0.898      0.836      0.902      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      2.42G     0.7293     0.4977     0.9578         22        640: 100% ━━━━━━━━━━━━ 39/39 3.6it/s 11.0s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.2it/s 0.6s<1.1s
#                    all         60         63      0.898      0.841      0.906      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      2.42G     0.6948     0.4637     0.9369         21        640: 100% ━━━━━━━━━━━━ 39/39 3.4it/s 11.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s<1.3s
#                    all         60         63      0.931      0.854      0.892      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      2.42G     0.6862     0.4698     0.9379         24        640: 100% ━━━━━━━━━━━━ 39/39 3.4it/s 11.5s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.3it/s 0.9s<1.6s
#                    all         60         63      0.902      0.905      0.906      0.519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      2.42G     0.6908       0.48     0.9455         22        640: 100% ━━━━━━━━━━━━ 39/39 2.9it/s 13.5s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s<1.3s
#                    all         60         63       0.93      0.889      0.905      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      2.42G     0.6758      0.455     0.9248         20        640: 100% ━━━━━━━━━━━━ 39/39 3.6it/s 10.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.2s
#                    all         60         63      0.947      0.851      0.891      0.497
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      2.42G     0.6762     0.4549      0.926         21        640: 100% ━━━━━━━━━━━━ 39/39 3.6it/s 10.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s<1.2s
#                    all         60         63      0.916       0.87      0.902      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      2.44G     0.6485      0.438     0.9326         21        640: 100% ━━━━━━━━━━━━ 39/39 3.6it/s 10.9s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.2s
#                    all         60         63      0.877      0.841      0.868      0.507
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      2.44G     0.6407     0.4365     0.9182         19        640: 100% ━━━━━━━━━━━━ 39/39 3.5it/s 11.0s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.2s
#                    all         60         63      0.867      0.857      0.874      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      2.44G      0.645     0.4452     0.9185         22        640: 100% ━━━━━━━━━━━━ 39/39 2.9it/s 13.7s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.2it/s 0.6s<1.1s
#                    all         60         63      0.922      0.841      0.917      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      2.44G     0.6435     0.4422     0.9269         18        640: 100% ━━━━━━━━━━━━ 39/39 3.6it/s 10.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.7it/s 0.7s<1.3s
#                    all         60         63      0.854      0.857      0.883      0.489
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      2.44G     0.6206     0.4306     0.9177         25        640: 100% ━━━━━━━━━━━━ 39/39 3.2it/s 12.0s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s<1.3s
#                    all         60         63      0.915      0.853      0.901      0.504
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      2.44G     0.6287     0.4239     0.9122         28        640: 100% ━━━━━━━━━━━━ 39/39 3.4it/s 11.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s<1.2s
#                    all         60         63       0.83      0.931      0.898      0.503
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      2.44G     0.6007     0.4084     0.9061         16        640: 100% ━━━━━━━━━━━━ 39/39 3.3it/s 11.9s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.2s
#                    all         60         63      0.913      0.873      0.898      0.497
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      2.44G      0.616     0.4209     0.9068         28        640: 100% ━━━━━━━━━━━━ 39/39 3.4it/s 11.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.4it/s 0.8s<1.4s
#                    all         60         63      0.862      0.889      0.902      0.502
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      2.44G     0.6166     0.4124     0.9123         16        640: 100% ━━━━━━━━━━━━ 39/39 2.7it/s 14.5s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.1it/s 0.6s<1.2s
#                    all         60         63      0.881      0.943      0.922        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      2.44G     0.6274     0.4256     0.9059         24        640: 100% ━━━━━━━━━━━━ 39/39 3.0it/s 13.0s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.7it/s 0.7s<1.4s
#                    all         60         63      0.892      0.916      0.894      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      2.44G     0.5855     0.4024     0.8941         26        640: 100% ━━━━━━━━━━━━ 39/39 3.0it/s 13.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.6it/s 0.8s<1.3s
#                    all         60         63      0.905      0.904      0.908      0.501
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      2.44G     0.5701     0.3932     0.8881         41        640: 100% ━━━━━━━━━━━━ 39/39 3.5it/s 11.0s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.1s
#                    all         60         63      0.912      0.825      0.885      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      2.44G     0.5758     0.3965     0.9004         12        640: 100% ━━━━━━━━━━━━ 39/39 3.8it/s 10.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s<1.2s
#                    all         60         63      0.845      0.873      0.883      0.509
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      2.44G     0.5603     0.3949     0.8914         25        640: 100% ━━━━━━━━━━━━ 39/39 3.5it/s 11.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.2s
#                    all         60         63       0.91      0.857      0.894      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      2.44G     0.5746     0.4051      0.898         21        640: 100% ━━━━━━━━━━━━ 39/39 3.5it/s 11.1s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.1it/s 0.6s<1.1s
#                    all         60         63      0.901      0.841      0.879      0.495
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      2.44G     0.5574     0.3836     0.8862         16        640: 100% ━━━━━━━━━━━━ 39/39 3.6it/s 10.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.7it/s 0.7s<1.4s
#                    all         60         63       0.93      0.839      0.906      0.509
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      2.44G     0.5478     0.3722     0.8963         22        640: 100% ━━━━━━━━━━━━ 39/39 3.8it/s 10.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.1it/s 0.7s<1.1s
#                    all         60         63      0.914      0.841      0.885      0.505
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      2.44G      0.548     0.3793     0.8826         23        640: 100% ━━━━━━━━━━━━ 39/39 3.6it/s 10.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.2s
#                    all         60         63        0.9      0.857       0.88      0.499
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      2.44G     0.5317     0.3757     0.8908         25        640: 100% ━━━━━━━━━━━━ 39/39 3.5it/s 11.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.2s
#                    all         60         63      0.908      0.841      0.884      0.498
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      2.44G     0.5364     0.3689     0.8845         23        640: 100% ━━━━━━━━━━━━ 39/39 3.8it/s 10.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.2s
#                    all         60         63      0.915      0.855       0.88      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      2.44G     0.5449     0.3921     0.8927         22        640: 100% ━━━━━━━━━━━━ 39/39 3.7it/s 10.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s<1.4s
#                    all         60         63        0.9      0.862      0.876      0.505
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      2.44G     0.5304     0.3698     0.8822         27        640: 100% ━━━━━━━━━━━━ 39/39 3.8it/s 10.2s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.2s
#                    all         60         63      0.947      0.857      0.901      0.502
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      2.44G     0.4745      0.332     0.8564         14        640: 100% ━━━━━━━━━━━━ 39/39 3.5it/s 11.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.1s
#                    all         60         63      0.918      0.888      0.915      0.505
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      2.44G     0.4584     0.3149     0.8413         14        640: 100% ━━━━━━━━━━━━ 39/39 3.6it/s 10.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.2s
#                    all         60         63      0.932      0.889      0.917      0.507
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      2.44G     0.4505     0.3082     0.8378         15        640: 100% ━━━━━━━━━━━━ 39/39 3.9it/s 10.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s<1.4s
#                    all         60         63      0.919      0.905      0.928      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      2.44G      0.441     0.3061     0.8347         16        640: 100% ━━━━━━━━━━━━ 39/39 3.7it/s 10.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.2s
#                    all         60         63      0.905      0.904      0.925      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      2.44G     0.4339     0.2995     0.8404         14        640: 100% ━━━━━━━━━━━━ 39/39 3.4it/s 11.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s<1.3s
#                    all         60         63      0.891      0.904      0.917      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      2.44G     0.4272     0.2975     0.8351         16        640: 100% ━━━━━━━━━━━━ 39/39 3.6it/s 10.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.1s
#                    all         60         63      0.892      0.873      0.891      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      2.44G     0.4026     0.2894     0.8327         14        640: 100% ━━━━━━━━━━━━ 39/39 3.7it/s 10.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s<1.2s
#                    all         60         63      0.919      0.902       0.92      0.512
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      2.44G      0.405     0.2934     0.8272         15        640: 100% ━━━━━━━━━━━━ 39/39 3.7it/s 10.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s<1.2s
#                    all         60         63      0.903      0.883      0.892      0.512
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      2.44G     0.4024     0.2862     0.8293         16        640: 100% ━━━━━━━━━━━━ 39/39 3.9it/s 10.1s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s<1.1s
#                    all         60         63      0.887      0.889      0.889      0.502
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      2.44G      0.401     0.2866     0.8242         14        640: 100% ━━━━━━━━━━━━ 39/39 3.9it/s 10.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.1it/s 0.7s<1.2s
#                    all         60         63      0.883      0.889      0.884      0.508
#
# 100 epochs completed in 0.369 hours.
# Optimizer stripped from runs\detect\train2\weights\last.pt, 6.3MB
# Optimizer stripped from runs\detect\train2\weights\best.pt, 6.3MB
#
# Validating runs\detect\train2\weights\best.pt...
# Ultralytics 8.3.191  Python-3.10.18 torch-2.8.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.4s<2.0s
#                    all         60         63      0.921      0.841      0.917      0.539
# Speed: 0.4ms preprocess, 6.1ms inference, 0.0ms loss, 3.0ms postprocess per image
# Results saved to runs\detect\train2

# %%
# !pip install pytesseract
# Out:
# Requirement already satisfied: pytesseract in c:\users\victus\anaconda3\envs\number_plate\lib\site-packages (0.3.13)
# Requirement already satisfied: packaging>=21.3 in c:\users\victus\anaconda3\envs\number_plate\lib\site-packages (from pytesseract) (25.0)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\victus\anaconda3\envs\number_plate\lib\site-packages (from pytesseract) (11.3.0)

# %%
import os
import sqlite3
from datetime import datetime
import cv2
import torch
from ultralytics import YOLO
import easyocr
import pytesseract
import numpy as np

# ---------------- CONFIG ----------------
CAM_ID = 0
DATA_DIR = "data"
PLATE_DIR = os.path.join(DATA_DIR, "plates")
DB_FILE = os.path.join(DATA_DIR, "anpr_logs.db")
MODEL_PATH = "best.pt"   # <-- your trained YOLOv8 model
MIN_PLATE_CONF = 0.50
DUPLICATE_SECONDS = 30
FRAME_SKIP = 2
SHOW_PREVIEW = True
ZONE = None

os.makedirs(PLATE_DIR, exist_ok=True)

# ---------- DATABASE ----------
def init_db():
    conn = sqlite3.connect(DB_FILE)
    c = conn.cursor()
    c.execute('''CREATE TABLE IF NOT EXISTS logs
                 (id INTEGER PRIMARY KEY,
                  plate TEXT,
                  vehicle_type TEXT,
                  confidence REAL,
                  timestamp TEXT,
                  camera_id TEXT,
                  image_path TEXT)''')
    conn.commit()
    return conn

def insert_log(conn, plate, vehicle_type, conf, ts, cam_id, img_path):
    c = conn.cursor()
    c.execute('INSERT INTO logs (plate, vehicle_type, confidence, timestamp, camera_id, image_path) VALUES (?, ?, ?, ?, ?, ?)',
              (plate, vehicle_type, conf, ts, cam_id, img_path))
    conn.commit()

# ---------- MODELS ----------
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Using device:", device)
det_model = YOLO(MODEL_PATH).to(device)

ocr = easyocr.Reader(['en'], gpu=torch.cuda.is_available())
recent_map = {}

# ---------- HELPERS ----------
def prep_plate_crop(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    gray = cv2.resize(gray, (300, 100), interpolation=cv2.INTER_CUBIC)
    gray = cv2.bilateralFilter(gray, 11, 17, 17)
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
    gray = clahe.apply(gray)
    return cv2.cvtColor(gray, cv2.COLOR_GRAY2BGR)

def run_ocr(img):
    results = ocr.readtext(img)
    if results:
        texts = [res[1] for res in results if res[2] > 0.6]
        if texts:
            clean_text = ''.join(ch for ch in texts[0] if ch.isalnum())
            return clean_text.upper()

    # fallback to Tesseract
    text = pytesseract.image_to_string(img, config="--psm 7")
    text = ''.join(ch for ch in text if ch.isalnum())
    return text.upper()

def stack_with_zoom(frame, plate_crop, plate_text):
    """Make side-by-side preview (frame + zoomed plate)."""
    zoomed = cv2.resize(plate_crop, (250, 100))
    cv2.putText(zoomed, plate_text, (10, 90),
                cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,255,0), 2)
    h, w, _ = frame.shape
    canvas = np.zeros((max(h, zoomed.shape[0]), w + zoomed.shape[1], 3), dtype=np.uint8)
    canvas[:h, :w] = frame
    canvas[:zoomed.shape[0], w:w+zoomed.shape[1]] = zoomed
    return canvas

def process_frame(frame, conn, cam_id="VideoFile"):
    global recent_map
    img_roi = frame if ZONE is None else frame[ZONE[1]:ZONE[3], ZONE[0]:ZONE[2]]
    results = det_model.predict(source=img_roi, conf=MIN_PLATE_CONF, iou=0.3, verbose=False)

    display_frame = frame.copy()
    for r in results:
        for box, conf in zip(r.boxes.xyxy.cpu().numpy(), r.boxes.conf.cpu().numpy()):
            x1, y1, x2, y2 = map(int, box)
            plate_crop = frame[y1:y2, x1:x2]
            if plate_crop.size == 0: continue

            proc = prep_plate_crop(plate_crop)
            plate_text = run_ocr(proc)
            if not plate_text or len(plate_text) < 4:
                continue

            now = datetime.now()
            duplicate = False
            if plate_text in recent_map and (now - recent_map[plate_text]).total_seconds() < DUPLICATE_SECONDS:
                duplicate = True
            recent_map[plate_text] = now

            # Save image + log
            ts = now.strftime("%Y%m%d_%H%M%S")
            fname = f"{plate_text}_{ts}.jpg"
            fpath = os.path.join(PLATE_DIR, fname)
            cv2.imwrite(fpath, plate_crop)
            insert_log(conn, plate_text, "unknown", float(conf), now.isoformat(), str(cam_id), fpath)

            # Draw detection
            color = (0,255,0) if not duplicate else (0,255,255)
            cv2.rectangle(display_frame, (x1, y1), (x2, y2), color, 3)
            cv2.putText(display_frame, f"{plate_text} ({conf:.2f})", (x1, y1-10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.8, color, 2)

            # Combine with zoomed-in plate
            display_frame = stack_with_zoom(display_frame, plate_crop, plate_text)

            print(f"[{'DUP' if duplicate else 'NEW'}] Plate: {plate_text} | Conf: {conf:.2f}")

    return display_frame

# ---------- VIDEO FUNCTIONS ----------
def run_on_video(video_path, save_output=False):
    conn = init_db()
    cap = cv2.VideoCapture(video_path)
    frame_idx = 0
    fps = cap.get(cv2.CAP_PROP_FPS) or 25

    if save_output:
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        out = cv2.VideoWriter("output.mp4", fourcc, fps,
                              (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))*2,  # width doubled (side-by-side)
                               int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))))

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret: break
        frame_idx += 1
        if frame_idx % FRAME_SKIP != 0: continue

        frame = process_frame(frame, conn, cam_id="VideoFile")

        # FPS counter
        cv2.putText(frame, f"FPS: {fps:.1f}", (20, 40),
                    cv2.FONT_HERSHEY_SIMPLEX, 1.0, (255, 0, 0), 2)

        if SHOW_PREVIEW: cv2.imshow("ANPR System", frame)
        if save_output: out.write(frame)
        if cv2.waitKey(1) & 0xFF == ord('q'): break

    cap.release(); conn.close()
    if save_output: out.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    run_on_video("C:/Users/VICTUS/Downloads/text_v.mp4", save_output=True)
# Out:
# Using device: cuda
# [NEW] Plate: GUNES | Conf: 0.65
# [NEW] Plate: BNAI3NRU | Conf: 0.74
# [NEW] Plate: OENRU | Conf: 0.74
# [NEW] Plate: PANIANRUW | Conf: 0.69
# [NEW] Plate: IBNAIANRU | Conf: 0.59
# [NEW] Plate: TENAHRU | Conf: 0.64
# [NEW] Plate: MJSSU | Conf: 0.53
# [NEW] Plate: TIINA | Conf: 0.63
# [NEW] Plate: UNERE | Conf: 0.71
# [NEW] Plate: DMBSIVSU | Conf: 0.51
# [NEW] Plate: EANAIZNRU | Conf: 0.63
# [NEW] Plate: LANAIRU | Conf: 0.68
# [NEW] Plate: MWSSU | Conf: 0.67
# [NEW] Plate: BANADNRU | Conf: 0.67
# [NEW] Plate: MNSVSU | Conf: 0.52
# [NEW] Plate: BANAINRU | Conf: 0.60
# [NEW] Plate: MWSISU | Conf: 0.82
# [NEW] Plate: 08NAIDNRU | Conf: 0.64
# [NEW] Plate: MWSIYSU | Conf: 0.74
# [NEW] Plate: BMWSVSU | Conf: 0.75
# [NEW] Plate: MWSVSU | Conf: 0.76
# [NEW] Plate: MWSIVSU | Conf: 0.81
# [NEW] Plate: TEKE | Conf: 0.78
# [NEW] Plate: SMWSIVSU | Conf: 0.71
# [DUP] Plate: MWSIVSU | Conf: 0.75
# [DUP] Plate: SMWSIVSU | Conf: 0.75
# [NEW] Plate: SMWSIWSU | Conf: 0.79
# [DUP] Plate: SMWSIVSU | Conf: 0.77
# [DUP] Plate: MWSSU | Conf: 0.78
# [NEW] Plate: MSYSU | Conf: 0.68
# [NEW] Plate: BMWSSU | Conf: 0.65
# [NEW] Plate: MSIYSU | Conf: 0.80
# [DUP] Plate: MWSIVSU | Conf: 0.79
# [DUP] Plate: MWSIYSU | Conf: 0.75
# [DUP] Plate: BMWSVSU | Conf: 0.59
# [NEW] Plate: MSIVSU | Conf: 0.77
# [DUP] Plate: MWSIVSU | Conf: 0.62
# [NEW] Plate: EGXISOCJE | Conf: 0.65
# [NEW] Plate: CXSOCI | Conf: 0.53
# [NEW] Plate: ECVIS0C | Conf: 0.57
# [NEW] Plate: RGXISOC | Conf: 0.65
# [NEW] Plate: POSJEG | Conf: 0.55
# [NEW] Plate: AELE | Conf: 0.57
# [NEW] Plate: TAPOSJOBY | Conf: 0.71
# [NEW] Plate: TAPASJEOUR | Conf: 0.76
# [NEW] Plate: EKIS3 | Conf: 0.61
# [NEW] Plate: TIPOSEOL | Conf: 0.73
# [NEW] Plate: BSLMI3VC | Conf: 0.64
# [NEW] Plate: TAPOSJEG | Conf: 0.58
# [NEW] Plate: CAPOSJED | Conf: 0.74
# [NEW] Plate: KSEE | Conf: 0.75
# [NEW] Plate: TAPOSJEOUY | Conf: 0.80
# [NEW] Plate: SAPOSJEGUS | Conf: 0.72
# [NEW] Plate: ELLE | Conf: 0.73
# [NEW] Plate: APOSJEOLE | Conf: 0.78
# [NEW] Plate: 05JET | Conf: 0.74
# [NEW] Plate: FAPOSJEON | Conf: 0.70
# [NEW] Plate: FAPOSJEOLY | Conf: 0.79
# [NEW] Plate: FAPOSJEG | Conf: 0.78
# [NEW] Plate: APOSJEOWW | Conf: 0.72
# [NEW] Plate: APOSJED | Conf: 0.51
# [NEW] Plate: APOEJEOUY | Conf: 0.78
# [NEW] Plate: APDSJEU | Conf: 0.53
# [NEW] Plate: EEAE | Conf: 0.58
# [NEW] Plate: PAPOSJEWW | Conf: 0.54
# [NEW] Plate: APOSJEOW | Conf: 0.80
# [NEW] Plate: APOSJEO | Conf: 0.67
# [DUP] Plate: APOSJED | Conf: 0.72
# [NEW] Plate: CAPOSJEOUW | Conf: 0.60
# [NEW] Plate: APOEJEOWS | Conf: 0.55
# [NEW] Plate: EFJI4ZHY | Conf: 0.58
# [NEW] Plate: FII4ZHY | Conf: 0.79
# [NEW] Plate: FALLAZHYF | Conf: 0.75
# [NEW] Plate: FJI4ZHY | Conf: 0.76
# [NEW] Plate: FJAZHY | Conf: 0.72
# [DUP] Plate: FJAZHY | Conf: 0.72
# [NEW] Plate: YCNOR | Conf: 0.65
# [NEW] Plate: YCITWER | Conf: 0.65
# [NEW] Plate: PEYGINEI | Conf: 0.64
# [NEW] Plate: EVEINAG | Conf: 0.58
# [NEW] Plate: EY6INBG | Conf: 0.51
# [NEW] Plate: AVDEAVFI | Conf: 0.59
# [NEW] Plate: WAVDGAVF | Conf: 0.57
# [NEW] Plate: BCSSUSS | Conf: 0.62
# [NEW] Plate: BL55USJ | Conf: 0.63
# [NEW] Plate: BGSUSI | Conf: 0.73
# [NEW] Plate: BGSSUSI | Conf: 0.72
# [NEW] Plate: BGSSUSJ | Conf: 0.55
# [NEW] Plate: BG5USI | Conf: 0.75
# [DUP] Plate: BGSSUSJ | Conf: 0.71
# [NEW] Plate: BGS6SUSJ | Conf: 0.75
# [NEW] Plate: BG6SUSJ | Conf: 0.74
# [DUP] Plate: BG6SUSJ | Conf: 0.70
# [DUP] Plate: BG6SUSJ | Conf: 0.71
# [DUP] Plate: BG6SUSJ | Conf: 0.75
# [NEW] Plate: BG6S5USI | Conf: 0.73
# [NEW] Plate: BG65USJ | Conf: 0.58
# [DUP] Plate: BG6SUSJ | Conf: 0.74
# [DUP] Plate: BG6SUSJ | Conf: 0.75
# [NEW] Plate: BG6S5US | Conf: 0.72
# [DUP] Plate: BG6SUSJ | Conf: 0.76
# [DUP] Plate: BG6SUSJ | Conf: 0.78
# [DUP] Plate: BG6SUSJ | Conf: 0.75
# [NEW] Plate: BGBSUSJ | Conf: 0.78
# [DUP] Plate: BGBSUSJ | Conf: 0.79
# [NEW] Plate: BGBSUSI | Conf: 0.74
# [NEW] Plate: BGGSUSJ | Conf: 0.77
# [NEW] Plate: BG65USI | Conf: 0.79
# [NEW] Plate: BG6SUSI | Conf: 0.76
# [DUP] Plate: BG65USJ | Conf: 0.77
# [DUP] Plate: BG6SUSJ | Conf: 0.79
# [NEW] Plate: 8665USJ | Conf: 0.71
# [DUP] Plate: 8665USJ | Conf: 0.71
# [DUP] Plate: 8665USJ | Conf: 0.77
# [DUP] Plate: 8665USJ | Conf: 0.73
# [DUP] Plate: BG6SUSJ | Conf: 0.71
# [NEW] Plate: 64DMY | Conf: 0.55
# [NEW] Plate: K64DMV | Conf: 0.59
# [NEW] Plate: AKG4DMV | Conf: 0.75
# [NEW] Plate: KEADP | Conf: 0.66
# [NEW] Plate: AKE4DMV | Conf: 0.79
# [NEW] Plate: AKG4DY | Conf: 0.62
# [NEW] Plate: RAKE4DAY | Conf: 0.75
# [NEW] Plate: AKG4DMY | Conf: 0.70
# [NEW] Plate: AKG4DKY | Conf: 0.51
# [DUP] Plate: AKE4DMV | Conf: 0.77
# [NEW] Plate: PAKE4ORV | Conf: 0.70
# [DUP] Plate: AKE4DMV | Conf: 0.74
# [NEW] Plate: EFIODZT | Conf: 0.53
# [DUP] Plate: AKE4DMV | Conf: 0.74
# [DUP] Plate: AKE4DMV | Conf: 0.73
# [NEW] Plate: AKE4DMY | Conf: 0.73
# [NEW] Plate: EFODZ | Conf: 0.61
# [DUP] Plate: AKG4DMV | Conf: 0.77
# [NEW] Plate: LAKE4DY | Conf: 0.77
# [DUP] Plate: AKG4DMY | Conf: 0.75
# [NEW] Plate: AKG4OMY | Conf: 0.75
# [DUP] Plate: EFIODZT | Conf: 0.55
# [DUP] Plate: AKG4DMV | Conf: 0.77
# [DUP] Plate: EFIODZT | Conf: 0.59
# [NEW] Plate: AKG4DHY | Conf: 0.63
# [DUP] Plate: AKE4DMV | Conf: 0.77
# [NEW] Plate: EFO0Z | Conf: 0.57
# [NEW] Plate: LAKE4DMY | Conf: 0.77
# [DUP] Plate: EFIODZT | Conf: 0.75
# [DUP] Plate: AKE4DMV | Conf: 0.71
# [DUP] Plate: AKE4DMV | Conf: 0.79
# [NEW] Plate: LAKE4DMV | Conf: 0.79
# [DUP] Plate: LAKE4DMV | Conf: 0.78
# [DUP] Plate: EFIODZT | Conf: 0.64
# [DUP] Plate: AKE4DMV | Conf: 0.77
# [DUP] Plate: EFIODZT | Conf: 0.64
# [NEW] Plate: AK64DMV | Conf: 0.76
# [DUP] Plate: EFIODZT | Conf: 0.70
# [DUP] Plate: AKE4DMV | Conf: 0.79
# [NEW] Plate: LAK64DMV | Conf: 0.80
# [DUP] Plate: EFIODZT | Conf: 0.66
# [DUP] Plate: AKG4DMV | Conf: 0.80
# [DUP] Plate: EFIODZT | Conf: 0.57
# [DUP] Plate: AK64DMV | Conf: 0.82
# [NEW] Plate: EFIOD2T | Conf: 0.73
# [DUP] Plate: EFIOD2T | Conf: 0.65
# [DUP] Plate: EFIODZT | Conf: 0.61
# [DUP] Plate: AK64DMV | Conf: 0.77
# [NEW] Plate: BEFIOD2T | Conf: 0.64
# [DUP] Plate: AKE4DMV | Conf: 0.83
# [DUP] Plate: AK64DMV | Conf: 0.81
# [NEW] Plate: SEFIOD2T | Conf: 0.64
# [DUP] Plate: AK64DMV | Conf: 0.79
# [DUP] Plate: EFIODZT | Conf: 0.67
# [NEW] Plate: PAKE4DMV | Conf: 0.74
# [DUP] Plate: LAKE4DMV | Conf: 0.77
# [DUP] Plate: EFIOD2T | Conf: 0.69
# [DUP] Plate: AKE4DMY | Conf: 0.73
# [DUP] Plate: EFIOD2T | Conf: 0.64
# [NEW] Plate: EFODZL | Conf: 0.68
# [NEW] Plate: AK64DMY | Conf: 0.64
# [DUP] Plate: EFIOD2T | Conf: 0.76
# [DUP] Plate: AK64DMV | Conf: 0.60
# [DUP] Plate: EFIOD2T | Conf: 0.70
# [DUP] Plate: EFIODZT | Conf: 0.60
# [DUP] Plate: EFIODZT | Conf: 0.70
# [DUP] Plate: EFODZL | Conf: 0.53
# [DUP] Plate: EFIODZT | Conf: 0.67
# [DUP] Plate: EFIOD2T | Conf: 0.77
# [DUP] Plate: EFIODZT | Conf: 0.60
# [DUP] Plate: EFODZL | Conf: 0.63
# [DUP] Plate: SEFIOD2T | Conf: 0.66
# [DUP] Plate: EFIOD2T | Conf: 0.68
# [NEW] Plate: TAFSSJKVJ | Conf: 0.54
# [NEW] Plate: AFESJKV | Conf: 0.52
# [NEW] Plate: ATESIKVB | Conf: 0.62
# [NEW] Plate: BARGSJKV | Conf: 0.51
# [NEW] Plate: PAFGSJKV | Conf: 0.63
# [NEW] Plate: PINSZC | Conf: 0.61
# [NEW] Plate: PINE | Conf: 0.61
# [NEW] Plate: KHOSKSU | Conf: 0.50
# [NEW] Plate: KHOUSKSU | Conf: 0.62
# [NEW] Plate: GJO6EPD | Conf: 0.74
# [NEW] Plate: BELNISZ2C | Conf: 0.58
# [NEW] Plate: GJIOSEPD | Conf: 0.75
# [NEW] Plate: 7GJOGEPD | Conf: 0.73
# [NEW] Plate: POSES | Conf: 0.73
# [NEW] Plate: GIOEPO | Conf: 0.53
# [NEW] Plate: GJOSEPD | Conf: 0.79
# [NEW] Plate: ELNIS2270 | Conf: 0.76
# [DUP] Plate: GJO6EPD | Conf: 0.55
# [NEW] Plate: GWJO6EPD | Conf: 0.67
# [NEW] Plate: SLMSZ2C | Conf: 0.66
# [DUP] Plate: GJO6EPD | Conf: 0.78
# [NEW] Plate: LNIS22C | Conf: 0.56
# [NEW] Plate: EUNISZ2ZC | Conf: 0.68
# [DUP] Plate: GJO6EPD | Conf: 0.66
# [NEW] Plate: GJDEPD | Conf: 0.64
# [NEW] Plate: FONEREC | Conf: 0.63
# [NEW] Plate: PINSEEE | Conf: 0.71
# [NEW] Plate: POUSEEE | Conf: 0.69
# [DUP] Plate: GJO6EPD | Conf: 0.65
# [NEW] Plate: LWSZZC | Conf: 0.69
# [NEW] Plate: BUNISZ2C | Conf: 0.73
# [NEW] Plate: UNISZ2C | Conf: 0.61
# [NEW] Plate: EUNIS22 | Conf: 0.73
# [NEW] Plate: QOBERD | Conf: 0.60
# [NEW] Plate: LZZC | Conf: 0.73
# [NEW] Plate: INSZ2C | Conf: 0.67
# [NEW] Plate: CITEERPD | Conf: 0.53
# [NEW] Plate: ELNISZZ2C | Conf: 0.69
# [DUP] Plate: GJO6EPD | Conf: 0.56
# [NEW] Plate: UNIS220 | Conf: 0.63
# [NEW] Plate: PLNIS22 | Conf: 0.68
# [NEW] Plate: GJIO6EPD | Conf: 0.50
# [NEW] Plate: LNISZ2C | Conf: 0.71
# [NEW] Plate: GCJIOEPD | Conf: 0.63
# [DUP] Plate: LNIS22C | Conf: 0.66
# [NEW] Plate: ELNISZ2C | Conf: 0.63
# [NEW] Plate: GOBERD | Conf: 0.79
# [DUP] Plate: LNISZ2C | Conf: 0.68
# [DUP] Plate: ELNISZ2C | Conf: 0.73
# [DUP] Plate: GJO6EPD | Conf: 0.57
# [NEW] Plate: LNISZZC | Conf: 0.76
# [NEW] Plate: DAO7CLX | Conf: 0.75
# [NEW] Plate: DAOCLX | Conf: 0.71
# [DUP] Plate: LNISZZC | Conf: 0.69
# [NEW] Plate: FUNIS77C | Conf: 0.75
# [DUP] Plate: LNISZ2C | Conf: 0.68
# [DUP] Plate: LNISZZC | Conf: 0.74
# [DUP] Plate: DAOCLX | Conf: 0.63
# [NEW] Plate: JAD7CLX | Conf: 0.57
# [NEW] Plate: LNIS2ZC | Conf: 0.78
# [DUP] Plate: DAOCLX | Conf: 0.61
# [DUP] Plate: LNISZ2C | Conf: 0.77
# [DUP] Plate: DAOCLX | Conf: 0.73
# [NEW] Plate: PUNIS77C | Conf: 0.72
# [DUP] Plate: JAD7CLX | Conf: 0.66
# [NEW] Plate: BLNISZZC | Conf: 0.76
# [DUP] Plate: LNISZZC | Conf: 0.77
# [DUP] Plate: DAOCLX | Conf: 0.57
# [DUP] Plate: LNISZZC | Conf: 0.73
# [DUP] Plate: DAOCLX | Conf: 0.70
# [NEW] Plate: PLANISZZC | Conf: 0.65
# [DUP] Plate: DAOCLX | Conf: 0.63
# [NEW] Plate: EVO3VES | Conf: 0.65
# [NEW] Plate: DAOCIXJ | Conf: 0.64
# [NEW] Plate: SEVOSVAS | Conf: 0.75
# [DUP] Plate: DAO7CLX | Conf: 0.73
# [NEW] Plate: SEYOSVUES | Conf: 0.74
# [DUP] Plate: DAO7CLX | Conf: 0.54
# [DUP] Plate: DAO7CLX | Conf: 0.68
# [NEW] Plate: SVVOSVES | Conf: 0.64
# [NEW] Plate: SBEYOSVAS | Conf: 0.80
# [DUP] Plate: DAOCLX | Conf: 0.74
# [NEW] Plate: SEYOSVES | Conf: 0.66
# [DUP] Plate: DAOCLX | Conf: 0.56
# [DUP] Plate: DAO7CLX | Conf: 0.71
# [NEW] Plate: EYOSVES | Conf: 0.57
# [DUP] Plate: DAO7CLX | Conf: 0.52
# [DUP] Plate: DAOCLX | Conf: 0.70
# [DUP] Plate: SEYOSVES | Conf: 0.67
# [NEW] Plate: SEOSVES | Conf: 0.76
# [NEW] Plate: DADCLX | Conf: 0.52
# [NEW] Plate: DAQ7OLX | Conf: 0.74
# [DUP] Plate: SEYOSVES | Conf: 0.73
# [NEW] Plate: DAOCLX7 | Conf: 0.71
# [DUP] Plate: SEYOSVES | Conf: 0.66
# [NEW] Plate: DAQ7CLX | Conf: 0.72
# [NEW] Plate: EYOSVS | Conf: 0.69
# [NEW] Plate: DAOTELX | Conf: 0.56
# [NEW] Plate: BEYOSWS | Conf: 0.74
# [NEW] Plate: DAOTOLX | Conf: 0.54
# [NEW] Plate: BEYOSVES | Conf: 0.70
# [NEW] Plate: AWMA | Conf: 0.70
# [DUP] Plate: DAO7CLX | Conf: 0.62
# [NEW] Plate: SEYOSVS | Conf: 0.73
# [NEW] Plate: WOWNA | Conf: 0.71
# [NEW] Plate: DAG7CLX | Conf: 0.60
# [NEW] Plate: SOWAE | Conf: 0.73
# [NEW] Plate: BEYOSVS | Conf: 0.73
# [DUP] Plate: DAOCLX | Conf: 0.61
# [NEW] Plate: 20WMA | Conf: 0.75
# [DUP] Plate: DAOTELX | Conf: 0.63
# [NEW] Plate: SOWMA | Conf: 0.61
# [DUP] Plate: BEYOSVES | Conf: 0.51
# [NEW] Plate: EYO9VES | Conf: 0.70
# [NEW] Plate: 50WNA | Conf: 0.68
# [DUP] Plate: SOWMA | Conf: 0.70
# [NEW] Plate: EYO9VS | Conf: 0.68
# [NEW] Plate: 160WHA | Conf: 0.77
# [DUP] Plate: DAOCLX | Conf: 0.73
# [NEW] Plate: TEVOSVS | Conf: 0.68
# [NEW] Plate: TOOWNA | Conf: 0.80
# [NEW] Plate: DADTELK | Conf: 0.76
# [NEW] Plate: EYO9VWS | Conf: 0.71
# [NEW] Plate: STERTE | Conf: 0.76
# [NEW] Plate: TEOUNA | Conf: 0.71
# [NEW] Plate: DOZX | Conf: 0.52
# [NEW] Plate: EYOSVWS | Conf: 0.74
# [NEW] Plate: T60WNA | Conf: 0.73
# [NEW] Plate: DADELX | Conf: 0.74
# [NEW] Plate: SEYOSVWS | Conf: 0.73
# [DUP] Plate: DAOCLX | Conf: 0.71
# [NEW] Plate: EYOSS | Conf: 0.70
# [DUP] Plate: DAOCLX | Conf: 0.74
# [NEW] Plate: SEYOSWS | Conf: 0.65
# [NEW] Plate: SEYOSVUS | Conf: 0.75
# [DUP] Plate: DAOCLX | Conf: 0.73
# [NEW] Plate: EYOSUS | Conf: 0.76
# [DUP] Plate: DAOCLX | Conf: 0.75
# [DUP] Plate: DADCLX | Conf: 0.72
# [NEW] Plate: ATERTE | Conf: 0.64
# [NEW] Plate: EYOSWS | Conf: 0.68
# [NEW] Plate: EYOSNS | Conf: 0.73
# [NEW] Plate: DOCX | Conf: 0.69
# [DUP] Plate: DADCLX | Conf: 0.70
# [NEW] Plate: SEYOSUS | Conf: 0.68
# [NEW] Plate: PEYOSVS | Conf: 0.76
# [DUP] Plate: EYOSNS | Conf: 0.76
# [NEW] Plate: EYOSYS | Conf: 0.75
# [NEW] Plate: EYOSYUS | Conf: 0.74
# [DUP] Plate: SEYOSWS | Conf: 0.75
# [DUP] Plate: SEYOSVWS | Conf: 0.75
# [DUP] Plate: SEYOSVS | Conf: 0.76
# [NEW] Plate: PEYOSVWS | Conf: 0.75
# [DUP] Plate: EYOSVS | Conf: 0.75
# [DUP] Plate: PEYOSVS | Conf: 0.78
# [DUP] Plate: PEYOSVS | Conf: 0.72
# [DUP] Plate: SEYOSVS | Conf: 0.77
# [NEW] Plate: SEYOSYWS | Conf: 0.77
# [NEW] Plate: BSEYOSVS | Conf: 0.76
# [NEW] Plate: EYOSVVWS | Conf: 0.80
# [DUP] Plate: SEYOSVWS | Conf: 0.77
# [DUP] Plate: SEYOSVWS | Conf: 0.77
# [DUP] Plate: BEYOSVS | Conf: 0.75
# [DUP] Plate: EYOSVWS | Conf: 0.78
# [NEW] Plate: SEEYOSVS | Conf: 0.75
# [DUP] Plate: SEYOSVUS | Conf: 0.77
# [NEW] Plate: EYOSVUS | Conf: 0.74
# [DUP] Plate: EYOSVWS | Conf: 0.75
# [DUP] Plate: EYOSVWS | Conf: 0.73
# [DUP] Plate: EYOSVWS | Conf: 0.75
# [DUP] Plate: EYOSVWS | Conf: 0.76
# [DUP] Plate: EYOSVWS | Conf: 0.79
# [NEW] Plate: EYOGU | Conf: 0.76
# [DUP] Plate: SEYOSVWS | Conf: 0.76
# [DUP] Plate: EYOSVWS | Conf: 0.74
# [DUP] Plate: EYOSVS | Conf: 0.77
# [DUP] Plate: EYOSVS | Conf: 0.74
# [DUP] Plate: EYOSVWS | Conf: 0.76
# [DUP] Plate: EYOSVWS | Conf: 0.74
# [DUP] Plate: EYOSVWS | Conf: 0.75
# [DUP] Plate: EYOSVWS | Conf: 0.81
# [DUP] Plate: EYOSS | Conf: 0.76
# [DUP] Plate: EYOSVWS | Conf: 0.77
# [DUP] Plate: EYOSVWS | Conf: 0.76
# [NEW] Plate: EYOSTE | Conf: 0.79
# [NEW] Plate: EYOSVWSS | Conf: 0.75
# [DUP] Plate: EYOSVWS | Conf: 0.80
# [DUP] Plate: EYOSVWS | Conf: 0.75
# [DUP] Plate: EYOSVWS | Conf: 0.77
# [DUP] Plate: EYOSVWSS | Conf: 0.77
# [DUP] Plate: EYOSVS | Conf: 0.74
# [DUP] Plate: EYOSVS | Conf: 0.71
# [NEW] Plate: BP53 | Conf: 0.84
# [NEW] Plate: ARE3T | Conf: 0.61
# [NEW] Plate: BPE3L | Conf: 0.64
# [NEW] Plate: BPEGSEE | Conf: 0.73
# [NEW] Plate: SBRE3 | Conf: 0.79
# [NEW] Plate: BPBLH | Conf: 0.81
# [NEW] Plate: BPEILYH | Conf: 0.70
# [DUP] Plate: BPEILYH | Conf: 0.81
# [NEW] Plate: BRPEILY | Conf: 0.81
# [NEW] Plate: BPELYH5 | Conf: 0.77
# [NEW] Plate: BPELY | Conf: 0.81
# [NEW] Plate: BP6E3LYH | Conf: 0.79
# [NEW] Plate: BP63LYH | Conf: 0.81
# [NEW] Plate: BPESLY | Conf: 0.79
# [NEW] Plate: BP6ILY | Conf: 0.74
# [DUP] Plate: BP6ILY | Conf: 0.78
# [DUP] Plate: BP63LYH | Conf: 0.75
# [DUP] Plate: BP63LYH | Conf: 0.77
# [NEW] Plate: BP53LYH | Conf: 0.78
# [DUP] Plate: BP63LYH | Conf: 0.82
# [DUP] Plate: BP63LYH | Conf: 0.82
# [DUP] Plate: BP63LYH | Conf: 0.79
# [DUP] Plate: BP63LYH | Conf: 0.76
# [DUP] Plate: BP63LYH | Conf: 0.76
# [DUP] Plate: BP63LYH | Conf: 0.79
# [DUP] Plate: BP63LYH | Conf: 0.78
# [NEW] Plate: BPEI3LY | Conf: 0.77
# [DUP] Plate: BP63LYH | Conf: 0.79
# [NEW] Plate: BP63LY | Conf: 0.80
# [NEW] Plate: BP3LY | Conf: 0.77
# [NEW] Plate: BPS3LYH | Conf: 0.74
# [DUP] Plate: BP63LY | Conf: 0.81
# [NEW] Plate: BPSILY | Conf: 0.79
# [NEW] Plate: BP6I3LY | Conf: 0.78
# [DUP] Plate: BP63LY | Conf: 0.77
# [DUP] Plate: BP63LYH | Conf: 0.80
# [DUP] Plate: BP63LYH | Conf: 0.78
# [DUP] Plate: BP63LYH | Conf: 0.78
# [NEW] Plate: BPBILY | Conf: 0.82
# [DUP] Plate: BPSILY | Conf: 0.77
# [DUP] Plate: BP63LY | Conf: 0.77
# [DUP] Plate: BPBILY | Conf: 0.80
# [DUP] Plate: BPBILY | Conf: 0.71
# [NEW] Plate: BPE3LYH | Conf: 0.76
# [NEW] Plate: WUCES2FX | Conf: 0.64
# [NEW] Plate: ACES7F | Conf: 0.76
# [NEW] Plate: WCEETES | Conf: 0.70
# [NEW] Plate: EDEE | Conf: 0.68
# [NEW] Plate: TWGEA | Conf: 0.72
# [NEW] Plate: WC65ZFX | Conf: 0.71
# [NEW] Plate: NLS40CX | Conf: 0.64
# [NEW] Plate: MELS4OCX | Conf: 0.70
# [NEW] Plate: EETSSOGX | Conf: 0.67
# [NEW] Plate: NL64OGX | Conf: 0.57
# [NEW] Plate: NLG4OGX | Conf: 0.72
# [DUP] Plate: NLG4OGX | Conf: 0.73
# [NEW] Plate: ML64OGX | Conf: 0.75
# [NEW] Plate: NLE4OGX | Conf: 0.69
# [DUP] Plate: NL64OGX | Conf: 0.81
# [NEW] Plate: ML64OGXX | Conf: 0.65
# [NEW] Plate: MLG4OGXX | Conf: 0.76
# [NEW] Plate: MI64OGXX | Conf: 0.80
# [NEW] Plate: NL640GX | Conf: 0.77
# [DUP] Plate: NL640GX | Conf: 0.77
# [NEW] Plate: ESBE | Conf: 0.65
# [DUP] Plate: NL64OGX | Conf: 0.60
# [DUP] Plate: NL64OGX | Conf: 0.78
# [DUP] Plate: NL64OGX | Conf: 0.78
# [NEW] Plate: CPII | Conf: 0.78
# [DUP] Plate: NL64OGX | Conf: 0.77
# [NEW] Plate: NL54OGX | Conf: 0.70
# [DUP] Plate: NL64OGX | Conf: 0.77
# [DUP] Plate: NL64OGX | Conf: 0.73
# [NEW] Plate: LPRI4 | Conf: 0.71
# [DUP] Plate: NL64OGX | Conf: 0.68
# [DUP] Plate: NL64OGX | Conf: 0.76
# [NEW] Plate: LRI4 | Conf: 0.51
# [DUP] Plate: NL64OGX | Conf: 0.77
# [DUP] Plate: NL64OGX | Conf: 0.79
# [DUP] Plate: NL64OGX | Conf: 0.76
# [NEW] Plate: LPI4 | Conf: 0.73
# [DUP] Plate: NL64OGX | Conf: 0.76
# [DUP] Plate: NL64OGX | Conf: 0.76
# [DUP] Plate: NL64OGX | Conf: 0.76
# [DUP] Plate: NL64OGX | Conf: 0.73
# [DUP] Plate: NL64OGX | Conf: 0.75
# [DUP] Plate: NL64OGX | Conf: 0.78
# [DUP] Plate: LPI4 | Conf: 0.75
# [DUP] Plate: NL64OGX | Conf: 0.76
# [NEW] Plate: LPIAL | Conf: 0.74
# [DUP] Plate: NL64OGX | Conf: 0.78
# [NEW] Plate: PPIA | Conf: 0.76
# [NEW] Plate: LPI4LIA | Conf: 0.81
# [DUP] Plate: NL64OGX | Conf: 0.79
# [DUP] Plate: NL64OGX | Conf: 0.79
# [NEW] Plate: EARS | Conf: 0.76
# [NEW] Plate: MERE | Conf: 0.79
# [DUP] Plate: NL54OGX | Conf: 0.78

# %%
"""
Optimized single-file ANPR pipeline (non-modular)
- YOLOv8 detection
- EasyOCR primary, Tesseract fallback
- Tracking + fast cleanup (bounding boxes removed quickly)
- Saves crops + logs to SQLite, writes output video
"""

import os, sqlite3, time, logging
from collections import deque, defaultdict
from datetime import datetime
import cv2, torch, numpy as np
from ultralytics import YOLO
import easyocr, pytesseract

# ================== CONFIG ==================
MODEL_PATH = "best.pt"
VIDEO_PATH = "C:/Users/VICTUS/Downloads/test2.mp4"  # or 0 for webcam
DATA_DIR = "data"
PLATE_DIR = os.path.join(DATA_DIR, "plates")
DB_FILE = os.path.join(DATA_DIR, "anpr_logs.db")

MIN_PLATE_CONF = 0.55
IMG_SIZE = 640
FRAME_SKIP = 3
DUP_PERIOD = 2
TRACK_IOU_THRESH = 0.35
VOTE_WINDOW = 6
VOTE_REQUIRED = 3
SAVE_CONF_THRESHOLD = 0.5
SHOW_PREVIEW = True
SAVE_PLATE_CROPS = True
LOG_TO_DB = True
USE_HALF = True
UPSCALE_THRESHOLD = 75

# cleanup times (short!)
FINALIZED_LINGER = 0.3      # seconds to keep green box after disappear
UNFINISHED_LINGER = 0.1     # seconds to keep yellow box after disappear

# ============================================
os.makedirs(PLATE_DIR, exist_ok=True)
logging.basicConfig(format="[%(levelname)s] %(asctime)s - %(message)s", level=logging.INFO)

# ---------- DB ----------
def init_db():
    if not LOG_TO_DB:
        return None
    conn = sqlite3.connect(DB_FILE)
    c = conn.cursor()
    c.execute("""CREATE TABLE IF NOT EXISTS logs (
        id INTEGER PRIMARY KEY,
        plate TEXT,
        confidence REAL,
        timestamp TEXT,
        camera_id TEXT,
        image_path TEXT
    )""")
    conn.commit()
    return conn

def insert_log(conn, plate, conf, ts, cam_id, img_path):
    if conn is None:
        return
    try:
        conn.execute('INSERT INTO logs (plate, confidence, timestamp, camera_id, image_path) VALUES (?,?,?,?,?)',
                     (plate, conf, ts, cam_id, img_path))
        conn.commit()
    except Exception as e:
        logging.error("DB ERROR: %s", e)

# ---------- models ----------
USE_CUDA = torch.cuda.is_available()
device = 'cuda' if USE_CUDA else 'cpu'
logging.info(f"Device: {device}")
det_model = YOLO(MODEL_PATH)
ocr_reader = easyocr.Reader(['en'], gpu=USE_CUDA)

# ---------- utilities ----------
COMMON_CONFUSIONS = {"O":"0","0":"O","I":"1","1":"I","B":"8","8":"B","S":"5","5":"S"}
def correct_text(s): return "".join(COMMON_CONFUSIONS.get(c,c) for c in s)
def tidy_text(s): return ''.join(ch for ch in s if ch.isalnum()).upper()

def iou_xyxy(a,b):
    ax1,ay1,ax2,ay2 = a; bx1,by1,bx2,by2 = b
    xi1, yi1 = max(ax1,bx1), max(ay1,by1)
    xi2, yi2 = min(ax2,bx2), min(ay2,by2)
    inter = max(0, xi2-xi1) * max(0, yi2-yi1)
    areaA = max(0,(ax2-ax1)) * max(0,(ay2-ay1))
    areaB = max(0,(bx2-bx1)) * max(0,(by2-by1))
    den = areaA + areaB - inter + 1e-6
    return inter/den

def normalize_bbox(b,w,h):
    x1,y1,x2,y2 = b
    return [max(0,int(x1)), max(0,int(y1)), min(w-1,int(x2)), min(h-1,int(y2))]

def ocr_candidates(img):
    out = []
    try:
        rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    except:
        rgb = img
    try:
        results = ocr_reader.readtext(rgb, detail=1)
        for bbox, text, conf in results:
            t = tidy_text(text)
            if t: out.append((correct_text(t), float(conf)))
    except: pass
    if not out:
        try:
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            _, th = cv2.threshold(gray,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
            txt = tidy_text(pytesseract.image_to_string(th, config="--psm 7"))
            if txt: out.append((correct_text(txt), 0.6))
        except: pass
    agg = defaultdict(float)
    for t,c in out: agg[t]+=float(c)
    items = [(t,agg[t]) for t in agg]
    items.sort(key=lambda x:x[1], reverse=True)
    return items

# ---------------- tracking ----------------
NEXT_TRACK_ID = 0
tracks = []
last_saved = {}

def create_track(bbox, conf, text, text_conf, crop, now_time):
    global NEXT_TRACK_ID
    t = {
        'id': NEXT_TRACK_ID,
        'bbox': bbox,
        'first_seen': now_time,
        'last_seen': now_time,
        'confs': deque([conf], maxlen=30),
        'texts': deque([(text, text_conf)], maxlen=20),
        'crops': deque([crop], maxlen=20),
        'frames': 1,
        'finalized': False
    }
    NEXT_TRACK_ID += 1
    return t

def match_track(bbox):
    best, best_iou = None, 0.0
    for t in tracks:
        i = iou_xyxy(bbox, t['bbox'])
        if i > best_iou: best_iou, best = i, t
    return best if best_iou >= TRACK_IOU_THRESH else None

def weighted_vote(pairs):
    weight = defaultdict(float)
    for t,c in pairs:
        if not t: continue
        weight[t]+=float(c)
    if not weight: return "",0.0
    return max(weight.items(), key=lambda x:x[1])

# --------------- main frame processing ---------------
def process_frame(frame, conn, cam_id="video"):
    global tracks, last_saved
    fh, fw = frame.shape[:2]
    results = det_model.predict(frame, conf=MIN_PLATE_CONF, imgsz=IMG_SIZE, device=device, verbose=False)
    dets=[]
    for r in results:
        xy=r.boxes.xyxy.cpu().numpy(); confs=r.boxes.conf.cpu().numpy()
        for (x1,y1,x2,y2), conf in zip(xy, confs):
            bb=normalize_bbox([x1,y1,x2,y2],fw,fh)
            dets.append((bb,float(conf)))
    now_time=time.time()
    for bb,conf in dets:
        x1,y1,x2,y2=bb
        if x2-x1<=8 or y2-y1<=8: continue
        crop=frame[y1:y2,x1:x2].copy()
        candidates=ocr_candidates(crop)
        text,tc=(candidates[0] if candidates else ("",0.0))
        matched=match_track(bb)
        if matched is None:
            t=create_track(bb,conf,text,tc,crop,now_time); tracks.append(t)
        else:
            matched['bbox']=[int(0.6*a+0.4*b) for a,b in zip(matched['bbox'],bb)]
            matched['last_seen']=now_time; matched['frames']+=1
            matched['confs'].append(conf); matched['crops'].append(crop)
            if candidates:
                for txt,cc in candidates: matched['texts'].append((txt,cc))
    disp=frame.copy()
    for t in list(tracks):
        age=time.time()-t['last_seen']
        # cleanup: remove quickly when disappeared
        if t['finalized'] and age>FINALIZED_LINGER:
            tracks.remove(t); continue
        if not t['finalized'] and age>UNFINISHED_LINGER:
            tracks.remove(t); continue
        if not t['finalized']:
            best_text,total=weighted_vote(list(t['texts']))
            if best_text and total>=VOTE_REQUIRED:
                ts=datetime.now().isoformat()
                fname=f"{best_text}_{datetime.now().strftime('%Y%m%d_%H%M%S')}.jpg"
                path=os.path.join(PLATE_DIR,fname) if SAVE_PLATE_CROPS else ""
                if SAVE_PLATE_CROPS: cv2.imwrite(path, t['crops'][-1])
                insert_log(conn,best_text,total,ts,cam_id,path)
                last_saved[best_text]=time.time()
                logging.info(f"[SAVED] {best_text} conf={total:.2f}")
                t['finalized']=True
        x1,y1,x2,y2=t['bbox']
        color=(0,255,0) if t['finalized'] else (0,165,255)
        cv2.rectangle(disp,(x1,y1),(x2,y2),color,2)
        top,_=weighted_vote(list(t['texts']))
        cv2.putText(disp, top if top else f"id:{t['id']}", (x1,max(12,y1-6)),
                    cv2.FONT_HERSHEY_SIMPLEX,0.7,color,2)
    return disp

# --------------- runner ----------------
def run_video(path=VIDEO_PATH, save_output=True, out_file="output_anpr.mp4"):
    conn=init_db()
    cap=cv2.VideoCapture(path if path is not None else 0)
    writer=None
    if save_output:
        fourcc=cv2.VideoWriter_fourcc(*'mp4v')
        fps=cap.get(cv2.CAP_PROP_FPS) or 25
        w,h=int(cap.get(3)),int(cap.get(4))
        writer=cv2.VideoWriter(out_file,fourcc,fps,(w,h))
    idx,start=0,time.time()
    while True:
        ret,frame=cap.read()
        if not ret: break
        idx+=1
        if idx%FRAME_SKIP: 
            if save_output and writer: writer.write(frame)
            continue
        out_frame=process_frame(frame,conn,os.path.basename(path))
        fps_est=idx/max(1e-3,(time.time()-start))
        cv2.putText(out_frame,f"FPS:{fps_est:.1f}",(8,30),
                    cv2.FONT_HERSHEY_SIMPLEX,1.0,(0,255,255),2)
        if SHOW_PREVIEW:
            cv2.imshow("ANPR (q to quit)",out_frame)
            if cv2.waitKey(1)&0xFF==ord('q'): break
        if save_output and writer:
            out_write=cv2.resize(out_frame,(w,h))
            writer.write(out_write)
    cap.release()
    if writer: writer.release()
    if conn: conn.close()
    cv2.destroyAllWindows()
    logging.info("Done.")

if __name__=="__main__":
    run_video()
# Out:
# [INFO] 2025-09-10 12:25:55,170 - Device: cuda
# [INFO] 2025-09-10 12:26:01,757 - [SAVED] RAV4 conf=3.98
# [INFO] 2025-09-10 12:26:05,634 - [SAVED] RAV4 conf=3.80
# [INFO] 2025-09-10 12:26:10,249 - [SAVED] T0Y0TA conf=3.79
# [INFO] 2025-09-10 12:26:13,942 - [SAVED] RAV4 conf=3.21
# [INFO] 2025-09-10 12:26:31,295 - [SAVED] T0Y0TA conf=3.90
# [INFO] 2025-09-10 12:26:33,006 - [SAVED] RAV4 conf=3.96
# [INFO] 2025-09-10 12:26:33,670 - [SAVED] T0Y0TA conf=3.54
# [INFO] 2025-09-10 12:26:38,192 - Done.
